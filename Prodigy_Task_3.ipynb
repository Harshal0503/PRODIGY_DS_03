# %% [markdown]
# # TASK 3

# %% [markdown]
# Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Reading CSV file

# %%
df = pd.read_csv('/content/sample_data/bank-additional.csv', delimiter=';')
df.rename(columns={'y':'subscribed_deposit'}, inplace=True)

# %% [markdown]
# Checking Top 10 rows

# %%
df.head(10)
# Out:
#    age           job   marital            education  default  housing  \
# 0   30   blue-collar   married             basic.9y       no      yes
# 1   39      services    single          high.school       no       no
# 2   25      services   married          high.school       no      yes
# 3   38      services   married             basic.9y       no  unknown
# 4   47        admin.   married    university.degree       no      yes
# 5   32      services    single    university.degree       no       no
# 6   32        admin.    single    university.degree       no      yes
# 7   41  entrepreneur   married    university.degree  unknown      yes
# 8   31      services  divorced  professional.course       no       no
# 9   35   blue-collar   married             basic.9y  unknown       no
#
#       loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 0       no   cellular   may         fri  ...         2    999         0
# 1       no  telephone   may         fri  ...         4    999         0
# 2       no  telephone   jun         wed  ...         1    999         0
# 3  unknown  telephone   jun         fri  ...         3    999         0
# 4       no   cellular   nov         mon  ...         1    999         0
# 5       no   cellular   sep         thu  ...         3    999         2
# 6       no   cellular   sep         mon  ...         4    999         0
# 7       no   cellular   nov         mon  ...         2    999         0
# 8       no   cellular   nov         tue  ...         1    999         1
# 9       no  telephone   may         thu  ...         1    999         0
#
#       poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent         -1.8          92.893          -46.2      1.313
# 1  nonexistent          1.1          93.994          -36.4      4.855
# 2  nonexistent          1.4          94.465          -41.8      4.962
# 3  nonexistent          1.4          94.465          -41.8      4.959
# 4  nonexistent         -0.1          93.200          -42.0      4.191
# 5      failure         -1.1          94.199          -37.5      0.884
# 6  nonexistent         -1.1          94.199          -37.5      0.879
# 7  nonexistent         -0.1          93.200          -42.0      4.191
# 8      failure         -0.1          93.200          -42.0      4.153
# 9  nonexistent          1.1          93.994          -36.4      4.855
#
#    nr.employed  subscribed_deposit
# 0       5099.1                  no
# 1       5191.0                  no
# 2       5228.1                  no
# 3       5228.1                  no
# 4       5195.8                  no
# 5       4963.6                  no
# 6       4963.6                  no
# 7       5195.8                  no
# 8       5195.8                  no
# 9       5191.0                  no
#
# [10 rows x 21 columns]

# %% [markdown]
# Checking bottom 10 rows

# %%
df.tail(10)
# Out:
#       age         job   marital            education  default  housing  \
# 4109   63     retired   married          high.school       no       no
# 4110   53   housemaid  divorced             basic.6y  unknown  unknown
# 4111   30  technician   married    university.degree       no       no
# 4112   31  technician    single  professional.course       no      yes
# 4113   31      admin.    single    university.degree       no      yes
# 4114   30      admin.   married             basic.6y       no      yes
# 4115   39      admin.   married          high.school       no      yes
# 4116   27     student    single          high.school       no       no
# 4117   58      admin.   married          high.school       no       no
# 4118   34  management    single          high.school       no      yes
#
#          loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 4109       no   cellular   oct         wed  ...         1    999         0
# 4110  unknown  telephone   may         fri  ...         2    999         0
# 4111      yes   cellular   jun         fri  ...         1    999         1
# 4112       no   cellular   nov         thu  ...         1    999         0
# 4113       no   cellular   nov         thu  ...         1    999         0
# 4114      yes   cellular   jul         thu  ...         1    999         0
# 4115       no  telephone   jul         fri  ...         1    999         0
# 4116       no   cellular   may         mon  ...         2    999         1
# 4117       no   cellular   aug         fri  ...         1    999         0
# 4118       no   cellular   nov         wed  ...         1    999         0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 4109  nonexistent         -3.4          92.431          -26.9      0.740
# 4110  nonexistent          1.1          93.994          -36.4      4.855
# 4111      failure         -1.7          94.055          -39.8      0.748
# 4112  nonexistent         -0.1          93.200          -42.0      4.076
# 4113  nonexistent         -0.1          93.200          -42.0      4.076
# 4114  nonexistent          1.4          93.918          -42.7      4.958
# 4115  nonexistent          1.4          93.918          -42.7      4.959
# 4116      failure         -1.8          92.893          -46.2      1.354
# 4117  nonexistent          1.4          93.444          -36.1      4.966
# 4118  nonexistent         -0.1          93.200          -42.0      4.120
#
#       nr.employed  subscribed_deposit
# 4109       5017.5                  no
# 4110       5191.0                  no
# 4111       4991.6                  no
# 4112       5195.8                  no
# 4113       5195.8                  no
# 4114       5228.1                  no
# 4115       5228.1                  no
# 4116       5099.1                  no
# 4117       5228.1                  no
# 4118       5195.8                  no
#
# [10 rows x 21 columns]

# %% [markdown]
# Info about dataset

# %%
df.shape
# Out:
# (4119, 21)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'subscribed_deposit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 4119 non-null   int64
#  1   job                 4119 non-null   object
#  2   marital             4119 non-null   object
#  3   education           4119 non-null   object
#  4   default             4119 non-null   object
#  5   housing             4119 non-null   object
#  6   loan                4119 non-null   object
#  7   contact             4119 non-null   object
#  8   month               4119 non-null   object
#  9   day_of_week         4119 non-null   object
#  10  duration            4119 non-null   int64
#  11  campaign            4119 non-null   int64
#  12  pdays               4119 non-null   int64
#  13  previous            4119 non-null   int64
#  14  poutcome            4119 non-null   object
#  15  emp.var.rate        4119 non-null   float64
#  16  cons.price.idx      4119 non-null   float64
#  17  cons.conf.idx       4119 non-null   float64
#  18  euribor3m           4119 non-null   float64
#  19  nr.employed         4119 non-null   float64
#  20  subscribed_deposit  4119 non-null   object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 675.9+ KB

# %%
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# min       -3.400000       92.201000     -50.800000     0.635000  4963.600000
# 25%       -1.800000       93.075000     -42.700000     1.334000  5099.100000
# 50%        1.100000       93.749000     -41.800000     4.857000  5191.000000
# 75%        1.400000       93.994000     -36.400000     4.961000  5228.100000
# max        1.400000       94.767000     -26.900000     5.045000  5228.100000

# %% [markdown]
# Checking for duplicated values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Checking null values

# %%
df.isna().sum()
# Out:
# age                   0
# job                   0
# marital               0
# education             0
# default               0
# housing               0
# loan                  0
# contact               0
# month                 0
# day_of_week           0
# duration              0
# campaign              0
# pdays                 0
# previous              0
# poutcome              0
# emp.var.rate          0
# cons.price.idx        0
# cons.conf.idx         0
# euribor3m             0
# nr.employed           0
# subscribed_deposit    0
# dtype: int64

# %% [markdown]
# Visualizing numerical data with histograph

# %%
df_object=df.select_dtypes(include='object')
df_numerical=df.select_dtypes(exclude='object')

# %%
for feature in df_numerical:
  sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')
  plt.show()
# Out:
# /tmp/ipython-input-1415702135.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')
# /tmp/ipython-input-1415702135.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')
# /tmp/ipython-input-1415702135.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')
# /tmp/ipython-input-1415702135.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')
# /tmp/ipython-input-1415702135.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')
# /tmp/ipython-input-1415702135.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')
# /tmp/ipython-input-1415702135.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')
# /tmp/ipython-input-1415702135.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')
# /tmp/ipython-input-1415702135.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')
# /tmp/ipython-input-1415702135.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x=feature, data=df, bins=25, kde=True, palette='viridis')

# %% [markdown]
# Making bar graph for category data

# %%
for feature in df_object:
  plt.figure(figsize=(8,3))
  plt.title(f'Count of {feature}')
  sns.countplot(x=feature, data=df, palette='viridis')
  plt.xticks(rotation=45)
  plt.show()
# Out:
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')
# /tmp/ipython-input-4079140893.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=feature, data=df, palette='viridis')

# %% [markdown]
# Checking for Outliners

# %%
df.plot(kind='box', subplots=True, layout=(5,2), figsize=(10,30))
plt.show()

# %% [markdown]
# Outliers Treatment

# %%
columns = ['age', 'campaign', 'duration']

for column in columns:
    q1 = np.percentile(df[column], 25)
    q3 = np.percentile(df[column], 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    # Filter the DataFrame for the current column
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
df.plot(kind='box', subplots=True, layout=(5,2), figsize=(10,30))
plt.show()

# %% [markdown]
# Checking for correlation using heatmap

# %%
# Select only the numerical columns
numerical_df = df.select_dtypes(include=[np.number])

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# Selecting high correlations

# %%
high_correlation_column = ['emp.var.rate', 'euribor3m', 'nr.employed']

# %% [markdown]
# Dropping data with high correlation

# %%
df1 = df.copy()  #making copy of dataset
df1.drop(high_correlation_column, inplace=True, axis=1)
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'cons.price.idx', 'cons.conf.idx',
#        'subscribed_deposit'],
#       dtype='object')

# %% [markdown]
# Conversion of categorial data into numerical data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_encoded = df1.apply(le.fit_transform)
df_encoded
# Out:
#       age  job  marital  education  default  housing  loan  contact  month  \
# 0      12    1        1          2        0        2     0        0      6
# 1      21    7        2          3        0        0     0        1      6
# 2       7    7        1          3        0        2     0        1      4
# 3      20    7        1          2        0        1     1        1      4
# 4      29    0        1          6        0        2     0        0      7
# ...   ...  ...      ...        ...      ...      ...   ...      ...    ...
# 4114   12    0        1          1        0        2     2        0      3
# 4115   21    0        1          3        0        2     0        1      3
# 4116    9    8        2          3        0        0     0        0      6
# 4117   40    0        1          3        0        0     0        0      1
# 4118   16    4        2          3        0        2     0        0      7
#
#       day_of_week  duration  campaign  pdays  previous  poutcome  \
# 0               0       474         1     18         0         1
# 1               0       343         3     18         0         1
# 2               4       224         0     18         0         1
# 3               0        14         2     18         0         1
# 4               1        55         0     18         0         1
# ...           ...       ...       ...    ...       ...       ...
# 4114            2        50         0     18         0         1
# 4115            0       216         0     18         0         1
# 4116            1        61         1     18         1         0
# 4117            0       509         0     18         0         1
# 4118            4       172         0     18         0         1
#
#       cons.price.idx  cons.conf.idx  subscribed_deposit
# 0                  8              4                   0
# 1                 18             16                   0
# 2                 23              8                   0
# 3                 23              8                   0
# 4                 11              7                   0
# ...              ...            ...                 ...
# 4114              17              6                   0
# 4115              17              6                   0
# 4116               8              4                   0
# 4117              13             17                   0
# 4118              11              7                   0
#
# [3573 rows x 18 columns]

# %% [markdown]
# Renaming y to deposit

# %%
df.rename(columns={'y':'deposit'}, inplace=True)

# %% [markdown]
# Checking for Target Values

# %%
df_encoded['subscribed_deposit'].value_counts()
# Out:
# subscribed_deposit
# 0    3295
# 1     278
# Name: count, dtype: int64

# %%
## independent variables
x = df_encoded.iloc[:,:-1]

## Target variable
y = df_encoded.iloc[:,-1]

# %% [markdown]
# Splitting data into train and test datasets

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2501, 17)
# (1072, 17)
# (2501,)
# (1072,)

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dc = DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=10)
dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=10)

# %% [markdown]
# Training and testing Accuracy

# %%
print("Training Acuuracy : ", dc.score(x_train,y_train))
print("Testing Accuracy : ", dc.score(x_test,y_test))
# Out:
# Training Acuuracy :  0.9488204718112755
# Testing Accuracy :  0.9225746268656716

# %%
y_pred=dc.predict(x_test)

# %% [markdown]
# Evaluating Prediction Accuracy

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9225746268656716

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[966  17]
#  [ 66  23]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       983
#            1       0.57      0.26      0.36        89
#
#     accuracy                           0.92      1072
#    macro avg       0.76      0.62      0.66      1072
# weighted avg       0.91      0.92      0.91      1072

# %% [markdown]
# Plotting Decision Tree

# %%
from sklearn.tree import plot_tree
feature_names=df.columns.tolist()
plt.figure(figsize=(40,20))
class_names=["class_0","class_1"]
plot_tree(dc, feature_names=feature_names, class_names=class_names, filled=True,fontsize=12)
plt.show()

# %% [markdown]
# Decision Tree Classifier

# %%
dc1=DecisionTreeClassifier(criterion='entropy',max_depth=5,min_samples_split=10)
dc1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=10)

# %% [markdown]
# Evaluating Training and testing accuracy

# %%
print("Training accuracy:",dc1.score(x_train,y_train))
print("Testing accuracy:",dc1.score(x_test,y_test))
# Out:
# Training accuracy: 0.9472211115553778
# Testing accuracy: 0.9272388059701493

# %%
y1_pred=dc1.predict(x_test)

# %% [markdown]
# Evaluating Prediction Accuracy

# %%
print(accuracy_score(y_test,y1_pred))
# Out:
# 0.9272388059701493

# %%
print(confusion_matrix(y_test,y1_pred))
# Out:
# [[970  13]
#  [ 65  24]]

# %%
print(classification_report(y_test,y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       983
#            1       0.65      0.27      0.38        89
#
#     accuracy                           0.93      1072
#    macro avg       0.79      0.63      0.67      1072
# weighted avg       0.91      0.93      0.91      1072

# %%
cn=['no','yes']
fn=x_train.columns
plt.figure(figsize=(40,20))
plot_tree(dc1, feature_names=fn.tolist(), class_names=cn, filled=True,fontsize=12)
plt.show()
